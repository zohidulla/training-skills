# %%
# !pip install requests flask

# %%
import requests

# %%
requests
# Out:
# <module 'requests' from 'C:\\Users\\zohid\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\requests\\__init__.py'>

# %%
import flask

# %%
flask
# Out:
# <module 'flask' from 'C:\\Users\\zohid\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flask\\__init__.py'>

# %%
result = requests.get('https://google.com')
result
# Out:
# <Response [200]>

# %%
result.content
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="uz"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="wFeZMkuaW5ouqZJQ9MJdeQ">(function(){var _g={kEI:\'JT93aY6hN5Xhp84P8djY-A8\',kEXPI:\'0,203005,1101198,2935842,14112,425602,270476,5249849,12469,36811574,25228681,217547,39774,61249,13359,709,15097,45962,94679,10217,3,10463,14749,18636,26230,25591,46339,9921,873,2,11042,4431,6292,16179,25896,15502,1382,4,1514,3355,195,150,261,3030,624,1750,2,5999,17,2668,11622,2,876,2229,5089,19,3007,28,768,23254,4903,8466,1034,4303,845,2047,1574,3,2842,9,27,8,2333,9,1,1,3,708,1012,1745,4,3510,3,11680,4,2171,13,12,3,44,240,297,5,1031,82,389,4,298,2265,42,42,5,2698,2870,298,3415,2845,2385,608,1275,7,2840,2,2332,6128,3909,2,5724,9,602,59,1590,4,1616,1769,2137,709,3806,447,1,2,197,3,2,625,3,1120,239,3,2140,3,2788,49,10,215,4
# ...
