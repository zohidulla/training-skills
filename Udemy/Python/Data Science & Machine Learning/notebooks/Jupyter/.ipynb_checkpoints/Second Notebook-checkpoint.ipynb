# %%
import os

# %%
os
# Out:
# <module 'os' (frozen)>

# %%
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
# ...

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\zohid\\AppData\\Roaming',
#         'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey',
#         'CHOCOLATEYLASTPATHUPDATE': '133458022355295968',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_4004_EJJXRSZMHDOCBBAN',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'MAIN778-IT',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'DOKANLIBRARY2': 'C:\\Program Files\\Dokan\\Dokan Library-2.2.1\\',
#         'DOKANLIBRARY2_LIBRARYPATH_X64': 'C:\\Program Files\\Dokan\\Dokan Library-2.2.1\\lib\\',
#         'DOKANLIBRARY2_LIBRARYPATH_X86': 'C:\\Program Files\\Dokan\\Dokan Library-2.2.1\\x86\\lib\\',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
# ...

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>
